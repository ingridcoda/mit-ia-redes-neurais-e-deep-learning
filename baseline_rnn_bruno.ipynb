# %% [markdown]
# # Baseline RNN para Previsão de Produtos (Otimizado para Mac M2 Max)
#
# Este notebook contempla a implementação de um modelo baseline de Rede Neural Recorrente (RNN) para previsão sequencial de produtos, com otimizações para Apple Silicon (M2 Max).
#
# ---
#
# ## Problema, Solução e Justificativa
#
# Este notebook aborda o problema de prever o próximo produto a ser comprado por um cliente, dado o histórico de compras anteriores (sequência de produtos em pedidos). Esse tipo de previsão é fundamental em cenários de recomendação, como sugerir produtos em e-commerces, otimizar estoques ou personalizar ofertas.
#
# A solução proposta utiliza uma Rede Neural Recorrente (RNN), que é um tipo de modelo de aprendizado de máquina especializado em aprender padrões em sequências de dados. No contexto deste código, a RNN aprende a identificar quais produtos costumam ser comprados em sequência, permitindo prever o próximo item provável de uma lista de compras.
#
# **Por que essa solução faz sentido?**
#
# - O problema é naturalmente sequencial: o que um cliente compra depende do que ele já comprou antes.
# - RNNs são projetadas para capturar dependências e padrões em sequências, sendo amplamente utilizadas em tarefas como previsão de séries temporais, processamento de linguagem natural e, neste caso, recomendação de produtos.
# - O código está otimizado para rodar em hardware moderno (Apple Silicon M2 Max), aproveitando aceleração de GPU e técnicas de processamento eficiente de dados, garantindo performance mesmo com grandes volumes de informação.
#
# ---
#
# ## Por que este modelo é adequado como baseline, mas não como modelo mais profundo?
#
# O modelo RNN simples utilizado aqui é ideal como baseline porque é fácil de implementar, rápido de treinar e fornece um ponto de partida claro para comparação com abordagens mais sofisticadas. Ele permite validar rapidamente se há sinal preditivo nos dados e estabelece uma referência mínima de desempenho.
#
# No entanto, RNNs simples apresentam limitações importantes:
#
# - Têm dificuldade em capturar dependências de longo prazo em sequências;
# - Podem sofrer com problemas de gradiente (explosão ou desaparecimento);
# - Geralmente, não alcançam o desempenho de arquiteturas mais avançadas, como LSTM, GRU ou modelos baseados em Transformers.
#
# Por isso, embora seja excelente para um primeiro experimento e para balizar melhorias, não é recomendável como solução final em cenários de produção ou quando se busca o melhor desempenho possível.
#
# ---
#
# ## Resumo
#
# Este projeto lê dados de pedidos, prepara sequências de produtos, treina uma RNN para prever o próximo produto e avalia o desempenho do modelo, tudo com explicações detalhadas e logs para facilitar o entendimento, mesmo para quem não é especialista em machine learning.

# %% [markdown]
# ## Preparação do ambiente
#
# Adicionando pacotes necessários para a implementação

# %%
import datetime
import glob
import os
import random
import sys
import time

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
from scipy import stats
from sklearn.metrics import classification_report, confusion_matrix, top_k_accuracy_score
from tensorflow import keras
from tensorflow.keras import mixed_precision
from tensorflow.keras.layers import Bidirectional, Dense, Embedding, SimpleRNN
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.sequence import pad_sequences
# Out:
# 2025-10-03 10:54:31.499285: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-10-03 10:54:31.547997: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-10-03 10:54:32.510020: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %% [markdown]
# ## Configuração Apple Silicon (M2 Max) e Reprodutibilidade
#
# Configurações para garantir performance máxima no Mac M2 Max, uso de GPU e reprodutibilidade dos resultados.

# %%
print("🔧 Configurando ambiente...")

print(" - Configurando variáveis de ambiente para execução...")
BATCH_SIZE = 8192
AUTOTUNE = tf.data.AUTOTUNE
OUTPUT_DIM = 512
RNN_UNITS = 512
EPOCHS = 300
BUFFER_SIZE = 10000
SEED = 42
FORCE_TRAINING = True

random.seed(SEED)
np.random.seed(SEED)
keras.utils.set_random_seed(SEED)

print(" - Otimizando Tensorflow para Apple Silicon (M2 Max)...")
os.environ["OMP_NUM_THREADS"] = "2"
os.environ["TF_NUM_INTRAOP_THREADS"] = "2"
os.environ["TF_NUM_INTEROP_THREADS"] = "2"
os.environ["TF_ENABLE_ONEDNN_OPTS"] = "0"
mixed_precision.set_global_policy("float32")
physical_gpus = tf.config.list_physical_devices('GPU')
physical_cpus = tf.config.experimental.list_physical_devices('CPU')
if physical_gpus:
    print(f"    GPU(s) encontrados.")
    for gpu in physical_gpus:
        print(f"    Detalhes: {str(tf.config.experimental.get_device_details(gpu))}")
elif physical_cpus:
    print(f"    Nao foram encontrados GPU(s), mas foram encontrados CPU(s).")
    for cpu in physical_cpus:
        print(f"    Detalhes: {str(tf.config.experimental.get_device_details(cpu))}")
else:
    print("Erro ao configurar.")
    sys.exit(1)

print("✅ Ambiente configurado.\n")
# Out:
# 🔧 Configurando ambiente...
#  - Configurando variáveis de ambiente para execução...
#  - Otimizando Tensorflow para Apple Silicon (M2 Max)...
#     GPU(s) encontrados.
#     Detalhes: {'compute_capability': (8, 9), 'device_name': 'NVIDIA GeForce RTX 4070 Ti SUPER'}
# ✅ Ambiente configurado.

# %% [markdown]
# ## 1. Carregar e Limpar Dados
#
# Leitura do arquivo de pedidos, remoção de inconsistências e outliers para garantir dados de qualidade para o modelo.

# %%
start = time.time()
print("📥 Lendo e limpando dados...")
df = pd.read_excel("Pedidos.xlsx", parse_dates=["DataFechamento"], engine='openpyxl')
df = df[(df["qtde_vendida"] >= 0) & (df["DataFechamento"].dt.year < 2025)]
df = df.drop_duplicates()
if "valor_pedido" in df.columns:
    z = stats.zscore(df['valor_pedido'].values, nan_policy='omit')
    df = df[(z > -3) & (z < 3)]
print(f"✅ Dados carregados e limpos. {len(df)} linhas restantes. ({time.time() - start:.2f}s)\n")
# Out:
# 📥 Lendo e limpando dados...
# ✅ Dados carregados e limpos. 1037982 linhas restantes. (86.32s)

# %% [markdown]
# ## 2. Mapear Produtos para IDs
#
# Transforma cada produto em um número inteiro único, necessário para o processamento em redes neurais.

# %%
print("🔢 Mapeando produtos para IDs inteiros...")
unique_products = df['codigo_produto'].unique()
product_to_int = {p: i + 1 for i, p in enumerate(unique_products)}  # 0 reservado para padding
df['product_id'] = df['codigo_produto'].map(product_to_int).astype(np.int32)
print(f"✅ {len(product_to_int)} produtos mapeados.\n")
# Out:
# 🔢 Mapeando produtos para IDs inteiros...
# ✅ 375 produtos mapeados.

# %% [markdown]
# ## 3. Gerar Sequências (Vetorizado)
#
# Gera pares de entrada/saída para o modelo, onde a entrada é uma sequência de produtos e a saída é o próximo produto.

# %%
def create_sequences_and_labels(sequences, max_len):
    X, y = [], []
    for seq in sequences:
        arr = np.array(seq, dtype=np.int32)
        for i in range(1, len(arr)):
            X.append(arr[max(0, i - max_len):i])
            y.append(arr[i])
    return X, y


max_len = 10
train_max_date = pd.to_datetime('2022-12-31')
val_max_date = pd.to_datetime('2023-12-31')

print("🧩 Gerando sequências de treino e teste...")
df_train = df[df['DataFechamento'] <= train_max_date]
df_test = df[df['DataFechamento'] > val_max_date]
train_sequences = df_train.groupby('numero_pedido')['product_id'].apply(list).values
test_sequences = df_test.groupby('numero_pedido')['product_id'].apply(list).values
X_train, y_train = create_sequences_and_labels(train_sequences, max_len)
X_test, y_test = create_sequences_and_labels(test_sequences, max_len)
X_train = pad_sequences(X_train, maxlen=max_len, padding='pre', dtype='int32')
X_test = pad_sequences(X_test, maxlen=max_len, padding='pre', dtype='int32')
y_train = np.array(y_train, dtype='int32')
y_test = np.array(y_test, dtype='int32')
print(f"✅ {len(X_train)} amostras de treino, {len(X_test)} de teste.\n")
# Out:
# 🧩 Gerando sequências de treino e teste...
# ✅ 465205 amostras de treino, 23399 de teste.

# %% [markdown]
# ## 4. Pipeline tf.data para Máxima Performance
#
# Cria pipelines eficientes para leitura e processamento dos dados durante o treinamento e avaliação.

# %%
print("⚡️ Criando pipeline tf.data para máxima performance...")


def make_dataset(X, y, training=True):
    ds = tf.data.Dataset.from_tensor_slices((X, y))
    if training:
        ds = ds.shuffle(buffer_size=min(BUFFER_SIZE, len(X)), seed=SEED)
    ds = ds.cache()
    ds = ds.batch(BATCH_SIZE).prefetch(AUTOTUNE)
    return ds


train_ds = make_dataset(X_train, y_train, training=True)
val_split = int(0.1 * len(X_train))
val_ds = make_dataset(X_train[:val_split], y_train[:val_split], training=False)
test_ds = make_dataset(X_test, y_test, training=False)
print("✅ Pipeline tf.data criado.\n")
# Out:
# ⚡️ Criando pipeline tf.data para máxima performance...
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1759499762.942358    5358 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13142 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4070 Ti SUPER, pci bus id: 0000:01:00.0, compute capability: 8.9
# ✅ Pipeline tf.data criado.

# %% [markdown]
# ## 5. Carregar Modelo Salvo, se existir
#
# Se existir um modelo .keras salvo, carrega o mais recente. Caso contrário, constrói e treina o modelo do zero.

# %%
def find_latest_keras_model(pattern="rnn_baseline_*.keras"):
    files = glob.glob(pattern)
    if not files:
        return None
    files.sort(key=os.path.getmtime, reverse=True)
    return files[0]


latest_keras = find_latest_keras_model() if not FORCE_TRAINING else None
model = None

if latest_keras:
    print(f"🔄 Modelo .keras encontrado. Carregando modelo mais recente: {latest_keras}")
    model = keras.models.load_model(latest_keras)
    print("✅ Modelo carregado com sucesso. Pulando etapas de construção e treinamento.\n")

# %% [markdown]
# ## 6. Modelo RNN Baseline
#
# Construção do modelo sequencial com camadas de Embedding, SimpleRNN e Dense, caso necessário.

# %%
if not latest_keras:
    print("🏗️ Modelo .keras não encontrado. Construindo modelo RNN baseline...")
    num_products = len(product_to_int) + 1
    model = Sequential([
        Embedding(input_dim=num_products, output_dim=OUTPUT_DIM, mask_zero=True, embeddings_initializer='he_normal'),
        SimpleRNN(RNN_UNITS, dropout=0.1, recurrent_dropout=0.1),
        Dense(num_products, activation='softmax')
    ])
    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=2e-3, clipnorm=1.0),
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )
    model.build(input_shape=(None, max_len))
    print(model.summary())
    print("✅ Modelo construído.\n")
# Out:
# 🏗️ Modelo .keras não encontrado. Construindo modelo RNN baseline...
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ (None, 10, 512)        │       192,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn (SimpleRNN)          │ (None, 512)            │       524,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 376)            │       192,888 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 910,200 (3.47 MB)
#  Trainable params: 910,200 (3.47 MB)
#  Non-trainable params: 0 (0.00 B)
# None
# ✅ Modelo construído.

# %% [markdown]
# ## 7. Treinamento
#
# Treinamento do modelo com callbacks para early stopping, redução de learning rate e salvamento do melhor modelo, caso necessário.

# %%
class TimeHistory(keras.callbacks.Callback):
    def __init__(self):
        self.epoch_time_start = None

    def on_epoch_begin(self, epoch, logs=None):
        self.epoch_time_start = time.time()

    def on_epoch_end(self, epoch, logs=None):
        print(f"⏱️ Tempo da época {epoch + 1}: {time.time() - self.epoch_time_start:.2f}s")


class LrLogger(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        lr = self.model.optimizer.learning_rate
        if hasattr(lr, 'numpy'):
            lr = lr.numpy()
        print(f"🔎 Learning rate atual: {lr:.6f}")


if not latest_keras:
    print("🚀 Iniciando treinamento...")
    callbacks = [
        keras.callbacks.EarlyStopping(monitor='val_loss', patience=2, restore_best_weights=True, min_delta=0.005,
                                      verbose=1),
        keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=1, min_lr=1e-5, verbose=1),
        keras.callbacks.ModelCheckpoint('best_rnn_baseline.keras', save_best_only=True, monitor='val_loss',
                                        verbose=1),
        LrLogger(),
        TimeHistory(),
    ]
    history = model.fit(
        train_ds,
        epochs=EPOCHS,
        validation_data=val_ds,
        callbacks=callbacks,
        verbose=2
    )
    print("✅ Treinamento finalizado.\n")
# Out:
# 🚀 Iniciando treinamento...
# Epoch 1/300
#
# Epoch 1: val_loss improved from None to 4.33700, saving model to best_rnn_baseline.keras
# 🔎 Learning rate atual: 0.002000
# ⏱️ Tempo da época 1: 2.03s
# 57/57 - 2s - 36ms/step - accuracy: 0.1011 - loss: 4.1910 - val_accuracy: 0.0985 - val_loss: 4.3370 - learning_rate: 0.0020
# Epoch 2/300
#
# Epoch 2: val_loss improved from 4.33700 to 4.25879, saving model to best_rnn_baseline.keras
# 🔎 Learning rate atual: 0.002000
# ⏱️ Tempo da época 2: 1.73s
# 57/57 - 2s - 30ms/step - accuracy: 0.1059 - loss: 4.1350 - val_accuracy: 0.1007 - val_loss: 4.2588 - learning_rate: 0.0020
# Epoch 3/300
#
# Epoch 3: val_loss improved from 4.25879 to 4.21216, saving model to best_rnn_baseline.keras
# 🔎 Learning rate atual: 0.002000
# ⏱️ Tempo da época 3: 4.67s
# 57/57 - 5s - 82ms/step - accuracy: 0.1092 - loss: 4.1050 - val_accuracy: 0.1042 - val_loss: 4.2122 - learning_rate: 0.0020
# Epoch 4/300
#
# Epoch 4: val_loss improved from 4.21216 to 4.19505, saving model to best_rnn_baseline.keras
# 🔎 Learning rate atual: 0.002000
# ⏱️ Tempo da época 4: 1.72s
# 57/57 - 2s - 30ms/step - accuracy: 0.1104 - loss: 4.0873 - val_accuracy: 0.1044 - val_loss: 4.1950 - learning_rate: 0.0020
# Epoch 5/300
#
# Epoch 5: val_loss improved from 4.19505 to 4.17545, saving model to best_rnn_baseline.keras
# 🔎 Learning rate atual: 0.002000
# ⏱️ Tempo da época 5: 1.72s
# 57/57 - 2s - 30ms/step - accuracy: 0.1119 - loss: 4.0710 - val_accuracy: 0.1064 - val_loss: 4.1755 - learning_rate: 0.0020
# Epoch 6/300
#
# Epoch 6: val_loss improved from 4.17545 to 4.16592, saving model to best_rnn_baseline.keras
# 🔎 Learning rate atual: 0.002000
# ⏱️ Tempo da época 6: 1.72s
# 57/57 - 2s - 30ms/step - accuracy: 0.1129 - loss: 4.0565 - val_accuracy: 0.1048 - val_loss: 4.1659 - learning_rate: 0.0020
# Epoch 7/300
#
# Epoch 7: val_loss improved from 4.16592 to 4.15841, saving model to best_rnn_baseline.keras
# 🔎 Learning rate atual: 0.002000
# ⏱️ Tempo da época 7: 1.71s
# 57/57 - 2s - 30ms/step - accuracy: 0.1138 - loss: 4.0464 - val_accuracy: 0.1048 - val_loss: 4.1584 - learning_rate: 0.0020
# Epoch 8/300
#
# Epoch 8: val_loss improved from 4.15841 to 4.15069, saving model to best_rnn_baseline.keras
# 🔎 Learning rate atual: 0.002000
# ⏱️ Tempo da época 8: 1.72s
# 57/57 - 2s - 30ms/step - accuracy: 0.1145 - loss: 4.0383 - val_accuracy: 0.1064 - val_loss: 4.1507 - learning_rate: 0.0020
# Epoch 9/300
#
# Epoch 9: val_loss improved from 4.15069 to 4.13597, saving model to best_rnn_baseline.keras
# 🔎 Learning rate atual: 0.002000
# ⏱️ Tempo da época 9: 1.71s
# 57/57 - 2s - 30ms/step - accuracy: 0.1149 - loss: 4.0287 - val_accuracy: 0.1072 - val_loss: 4.1360 - learning_rate: 0.0020
# Epoch 10/300
#
# Epoch 10: val_loss improved from 4.13597 to 4.12982, saving model to best_rnn_baseline.keras
# 🔎 Learning rate atual: 0.002000
# ⏱️ Tempo da época 10: 1.71s
# 57/57 - 2s - 30ms/step - accuracy: 0.1159 - loss: 4.0202 - val_accuracy: 0.1051 - val_loss: 4.1298 - learning_rate: 0.0020
# Epoch 11/300
#
# Epoch 11: val_loss improved from 4.12982 to 4.12803, saving model to best_rnn_baseline.keras
# 🔎 Learning rate atual: 0.002000
# ⏱️ Tempo da época 11: 1.69s
# 57/57 - 2s - 30ms/step - accuracy: 0.1164 - loss: 4.0142 - val_accuracy: 0.1059 - val_loss: 4.1280 - learning_rate: 0.0020
# Epoch 12/300
#
# Epoch 12: val_loss improved from 4.12803 to 4.11392, saving model to best_rnn_baseline.keras
# 🔎 Learning rate atual: 0.002000
# ⏱️ Tempo da época 12: 1.63s
# 57/57 - 2s - 29ms/step - accuracy: 0.1168 - loss: 4.0095 - val_accuracy: 0.1077 - val_loss: 4.1139 - learning_rate: 0.0020
# Epoch 13/300
#
# Epoch 13: val_loss improved from 4.11392 to 4.11150, saving model to best_rnn_baseline.keras
# 🔎 Learning rate atual: 0.002000
# ⏱️ Tempo da época 13: 1.62s
# 57/57 - 2s - 28ms/step - accuracy: 0.1175 - loss: 4.0023 - val_accuracy: 0.1060 - val_loss: 4.1115 - learning_rate: 0.0020
# Epoch 14/300
#
# Epoch 14: val_loss improved from 4.11150 to 4.10452, saving model to best_rnn_baseline.keras
# 🔎 Learning rate atual: 0.002000
# ⏱️ Tempo da época 14: 1.63s
# 57/57 - 2s - 29ms/step - accuracy: 0.1180 - loss: 3.9945 - val_accuracy: 0.1062 - val_loss: 4.1045 - learning_rate: 0.0020
# Epoch 15/300
#
# Epoch 15: val_loss improved from 4.10452 to 4.09439, saving model to best_rnn_baseline.keras
# 🔎 Learning rate atual: 0.002000
# ⏱️ Tempo da época 15: 1.63s
# 57/57 - 2s - 29ms/step - accuracy: 0.1183 - loss: 3.9907 - val_accuracy: 0.1053 - val_loss: 4.0944 - learning_rate: 0.0020
# Epoch 16/300
#
# Epoch 16: val_loss improved from 4.09439 to 4.08139, saving model to best_rnn_baseline.keras
# 🔎 Learning rate atual: 0.002000
# ⏱️ Tempo da época 16: 1.63s
# 57/57 - 2s - 29ms/step - accuracy: 0.1190 - loss: 3.9861 - val_accuracy: 0.1066 - val_loss: 4.0814 - learning_rate: 0.0020
# Epoch 17/300
#
# Epoch 17: val_loss improved from 4.08139 to 4.07555, saving model to best_rnn_baseline.keras
# 🔎 Learning rate atual: 0.002000
# ⏱️ Tempo da época 17: 1.63s
# 57/57 - 2s - 29ms/step - accuracy: 0.1197 - loss: 3.9802 - val_accuracy: 0.1083 - val_loss: 4.0755 - learning_rate: 0.0020
# Epoch 18/300
#
# Epoch 18: val_loss improved from 4.07555 to 4.06638, saving model to best_rnn_baseline.keras
# 🔎 Learning rate atual: 0.002000
# ⏱️ Tempo da época 18: 1.66s
# 57/57 - 2s - 29ms/step - accuracy: 0.1203 - loss: 3.9742 - val_accuracy: 0.1087 - val_loss: 4.0664 - learning_rate: 0.0020
# Epoch 19/300
#
# Epoch 19: val_loss improved from 4.06638 to 4.05624, saving model to best_rnn_baseline.keras
# 🔎 Learning rate atual: 0.002000
# ⏱️ Tempo da época 19: 1.67s
# 57/57 - 2s - 29ms/step - accuracy: 0.1204 - loss: 3.9706 - val_accuracy: 0.1088 - val_loss: 4.0562 - learning_rate: 0.0020
# Epoch 20/300
#
# Epoch 20: val_loss improved from 4.05624 to 4.05127, saving model to best_rnn_baseline.keras
# 🔎 Learning rate atual: 0.002000
# ⏱️ Tempo da época 20: 1.76s
# 57/57 - 2s - 31ms/step - accuracy: 0.1214 - loss: 3.9624 - val_accuracy: 0.1096 - val_loss: 4.0513 - learning_rate: 0.0020
# Epoch 21/300
#
# Epoch 21: val_loss improved from 4.05127 to 4.04317, saving model to best_rnn_baseline.keras
# 🔎 Learning rate atual: 0.002000
# ⏱️ Tempo da época 21: 1.65s
# 57/57 - 2s - 29ms/step - accuracy: 0.1213 - loss: 3.9605 - val_accuracy: 0.1092 - val_loss: 4.0432 - learning_rate: 0.0020
# Epoch 22/300
#
# Epoch 22: val_loss improved from 4.04317 to 4.03946, saving model to best_rnn_baseline.keras
# 🔎 Learning rate atual: 0.002000
# ⏱️ Tempo da época 22: 4.63s
# 57/57 - 5s - 81ms/step - accuracy: 0.1219 - loss: 3.9561 - val_accuracy: 0.1129 - val_loss: 4.0395 - learning_rate: 0.0020
# Epoch 23/300
#
# Epoch 23: val_loss improved from 4.03946 to 4.03537, saving model to best_rnn_baseline.keras
# 🔎 Learning rate atual: 0.002000
# ⏱️ Tempo da época 23: 1.65s
# 57/57 - 2s - 29ms/step - accuracy: 0.1225 - loss: 3.9509 - val_accuracy: 0.1112 - val_loss: 4.0354 - learning_rate: 0.0020
# Epoch 24/300
#
# Epoch 24: val_loss improved from 4.03537 to 4.01537, saving model to best_rnn_baseline.keras
# 🔎 Learning rate atual: 0.002000
# ⏱️ Tempo da época 24: 1.63s
# 57/57 - 2s - 29ms/step - accuracy: 0.1231 - loss: 3.9459 - val_accuracy: 0.1123 - val_loss: 4.0154 - learning_rate: 0.0020
# Epoch 25/300
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0010000000474974513.
#
# Epoch 25: val_loss did not improve from 4.01537
# 🔎 Learning rate atual: 0.001000
# ⏱️ Tempo da época 25: 1.59s
# 57/57 - 2s - 28ms/step - accuracy: 0.1235 - loss: 3.9425 - val_accuracy: 0.1136 - val_loss: 4.0181 - learning_rate: 0.0020
# Epoch 26/300
#
# Epoch 26: val_loss improved from 4.01537 to 3.93611, saving model to best_rnn_baseline.keras
# 🔎 Learning rate atual: 0.001000
# ⏱️ Tempo da época 26: 1.62s
# 57/57 - 2s - 28ms/step - accuracy: 0.1245 - loss: 3.9261 - val_accuracy: 0.1219 - val_loss: 3.9361 - learning_rate: 0.0010
# Epoch 27/300
#
# Epoch 27: val_loss improved from 3.93611 to 3.91908, saving model to best_rnn_baseline.keras
# 🔎 Learning rate atual: 0.001000
# ⏱️ Tempo da época 27: 1.64s
# 57/57 - 2s - 29ms/step - accuracy: 0.1259 - loss: 3.9038 - val_accuracy: 0.1224 - val_loss: 3.9191 - learning_rate: 0.0010
# Epoch 28/300
#
# Epoch 28: val_loss improved from 3.91908 to 3.90639, saving model to best_rnn_baseline.keras
# 🔎 Learning rate atual: 0.001000
# ⏱️ Tempo da época 28: 1.62s
# 57/57 - 2s - 28ms/step - accuracy: 0.1268 - loss: 3.8956 - val_accuracy: 0.1234 - val_loss: 3.9064 - learning_rate: 0.0010
# Epoch 29/300
#
# Epoch 29: val_loss improved from 3.90639 to 3.89687, saving model to best_rnn_baseline.keras
# 🔎 Learning rate atual: 0.001000
# ⏱️ Tempo da época 29: 1.67s
# 57/57 - 2s - 29ms/step - accuracy: 0.1276 - loss: 3.8898 - val_accuracy: 0.1258 - val_loss: 3.8969 - learning_rate: 0.0010
# Epoch 30/300
#
# Epoch 30: val_loss improved from 3.89687 to 3.88899, saving model to best_rnn_baseline.keras
# 🔎 Learning rate atual: 0.001000
# ⏱️ Tempo da época 30: 1.63s
# 57/57 - 2s - 29ms/step - accuracy: 0.1277 - loss: 3.8856 - val_accuracy: 0.1255 - val_loss: 3.8890 - learning_rate: 0.0010
# Epoch 31/300
#
# Epoch 31: val_loss improved from 3.88899 to 3.88475, saving model to best_rnn_baseline.keras
# 🔎 Learning rate atual: 0.001000
# ⏱️ Tempo da época 31: 1.66s
# 57/57 - 2s - 29ms/step - accuracy: 0.1283 - loss: 3.8806 - val_accuracy: 0.1283 - val_loss: 3.8847 - learning_rate: 0.0010
# Epoch 32/300
#
# Epoch 32: val_loss improved from 3.88475 to 3.88083, saving model to best_rnn_baseline.keras
# 🔎 Learning rate atual: 0.001000
# ⏱️ Tempo da época 32: 1.72s
# 57/57 - 2s - 30ms/step - accuracy: 0.1289 - loss: 3.8767 - val_accuracy: 0.1267 - val_loss: 3.8808 - learning_rate: 0.0010
# Epoch 33/300
#
# Epoch 33: val_loss improved from 3.88083 to 3.87653, saving model to best_rnn_baseline.keras
# 🔎 Learning rate atual: 0.001000
# ⏱️ Tempo da época 33: 1.71s
# 57/57 - 2s - 30ms/step - accuracy: 0.1292 - loss: 3.8730 - val_accuracy: 0.1264 - val_loss: 3.8765 - learning_rate: 0.0010
# Epoch 34/300
#
# Epoch 34: val_loss improved from 3.87653 to 3.87144, saving model to best_rnn_baseline.keras
# 🔎 Learning rate atual: 0.001000
# ⏱️ Tempo da época 34: 1.71s
# 57/57 - 2s - 30ms/step - accuracy: 0.1297 - loss: 3.8697 - val_accuracy: 0.1269 - val_loss: 3.8714 - learning_rate: 0.0010
# Epoch 35/300
#
# Epoch 35: val_loss improved from 3.87144 to 3.86746, saving model to best_rnn_baseline.keras
# 🔎 Learning rate atual: 0.001000
# ⏱️ Tempo da época 35: 1.72s
# 57/57 - 2s - 30ms/step - accuracy: 0.1299 - loss: 3.8666 - val_accuracy: 0.1286 - val_loss: 3.8675 - learning_rate: 0.0010
# Epoch 36/300
#
# Epoch 36: val_loss improved from 3.86746 to 3.86062, saving model to best_rnn_baseline.keras
# 🔎 Learning rate atual: 0.001000
# ⏱️ Tempo da época 36: 1.72s
# 57/57 - 2s - 30ms/step - accuracy: 0.1307 - loss: 3.8622 - val_accuracy: 0.1288 - val_loss: 3.8606 - learning_rate: 0.0010
# Epoch 37/300
#
# Epoch 37: val_loss improved from 3.86062 to 3.85636, saving model to best_rnn_baseline.keras
# 🔎 Learning rate atual: 0.001000
# ⏱️ Tempo da época 37: 1.66s
# 57/57 - 2s - 29ms/step - accuracy: 0.1308 - loss: 3.8588 - val_accuracy: 0.1296 - val_loss: 3.8564 - learning_rate: 0.0010
# Epoch 38/300
#
# Epoch 38: val_loss improved from 3.85636 to 3.85266, saving model to best_rnn_baseline.keras
# 🔎 Learning rate atual: 0.001000
# ⏱️ Tempo da época 38: 1.64s
# 57/57 - 2s - 29ms/step - accuracy: 0.1312 - loss: 3.8551 - val_accuracy: 0.1276 - val_loss: 3.8527 - learning_rate: 0.0010
# Epoch 39/300
#
# Epoch 39: val_loss improved from 3.85266 to 3.84972, saving model to best_rnn_baseline.keras
# 🔎 Learning rate atual: 0.001000
# ⏱️ Tempo da época 39: 1.68s
# 57/57 - 2s - 30ms/step - accuracy: 0.1317 - loss: 3.8506 - val_accuracy: 0.1299 - val_loss: 3.8497 - learning_rate: 0.0010
# Epoch 40/300
#
# Epoch 40: val_loss improved from 3.84972 to 3.84571, saving model to best_rnn_baseline.keras
# 🔎 Learning rate atual: 0.001000
# ⏱️ Tempo da época 40: 1.66s
# 57/57 - 2s - 29ms/step - accuracy: 0.1322 - loss: 3.8479 - val_accuracy: 0.1295 - val_loss: 3.8457 - learning_rate: 0.0010
# Epoch 41/300
#
# Epoch 41: val_loss improved from 3.84571 to 3.84221, saving model to best_rnn_baseline.keras
# 🔎 Learning rate atual: 0.001000
# ⏱️ Tempo da época 41: 1.65s
# 57/57 - 2s - 29ms/step - accuracy: 0.1324 - loss: 3.8452 - val_accuracy: 0.1319 - val_loss: 3.8422 - learning_rate: 0.0010
# Epoch 42/300
#
# Epoch 42: val_loss improved from 3.84221 to 3.83761, saving model to best_rnn_baseline.keras
# 🔎 Learning rate atual: 0.001000
# ⏱️ Tempo da época 42: 4.61s
# 57/57 - 5s - 81ms/step - accuracy: 0.1327 - loss: 3.8421 - val_accuracy: 0.1321 - val_loss: 3.8376 - learning_rate: 0.0010
# Epoch 43/300
#
# Epoch 43: val_loss improved from 3.83761 to 3.83388, saving model to best_rnn_baseline.keras
# 🔎 Learning rate atual: 0.001000
# ⏱️ Tempo da época 43: 1.68s
# 57/57 - 2s - 30ms/step - accuracy: 0.1332 - loss: 3.8400 - val_accuracy: 0.1341 - val_loss: 3.8339 - learning_rate: 0.0010
# Epoch 44/300
#
# Epoch 44: val_loss improved from 3.83388 to 3.83030, saving model to best_rnn_baseline.keras
# 🔎 Learning rate atual: 0.001000
# ⏱️ Tempo da época 44: 1.62s
# 57/57 - 2s - 28ms/step - accuracy: 0.1335 - loss: 3.8362 - val_accuracy: 0.1323 - val_loss: 3.8303 - learning_rate: 0.0010
# Epoch 45/300
#
# Epoch 45: val_loss improved from 3.83030 to 3.82636, saving model to best_rnn_baseline.keras
# 🔎 Learning rate atual: 0.001000
# ⏱️ Tempo da época 45: 1.61s
# 57/57 - 2s - 28ms/step - accuracy: 0.1335 - loss: 3.8334 - val_accuracy: 0.1326 - val_loss: 3.8264 - learning_rate: 0.0010
# Epoch 46/300
#
# Epoch 46: val_loss improved from 3.82636 to 3.82309, saving model to best_rnn_baseline.keras
# 🔎 Learning rate atual: 0.001000
# ⏱️ Tempo da época 46: 1.67s
# 57/57 - 2s - 29ms/step - accuracy: 0.1343 - loss: 3.8306 - val_accuracy: 0.1318 - val_loss: 3.8231 - learning_rate: 0.0010
# Epoch 47/300
#
# Epoch 47: val_loss improved from 3.82309 to 3.82057, saving model to best_rnn_baseline.keras
# 🔎 Learning rate atual: 0.001000
# ⏱️ Tempo da época 47: 1.73s
# 57/57 - 2s - 30ms/step - accuracy: 0.1347 - loss: 3.8278 - val_accuracy: 0.1302 - val_loss: 3.8206 - learning_rate: 0.0010
# Epoch 48/300
#
# Epoch 48: val_loss improved from 3.82057 to 3.81670, saving model to best_rnn_baseline.keras
# 🔎 Learning rate atual: 0.001000
# ⏱️ Tempo da época 48: 1.72s
# 57/57 - 2s - 30ms/step - accuracy: 0.1350 - loss: 3.8248 - val_accuracy: 0.1320 - val_loss: 3.8167 - learning_rate: 0.0010
# Epoch 49/300
#
# Epoch 49: val_loss improved from 3.81670 to 3.81295, saving model to best_rnn_baseline.keras
# 🔎 Learning rate atual: 0.001000
# ⏱️ Tempo da época 49: 1.72s
# 57/57 - 2s - 30ms/step - accuracy: 0.1350 - loss: 3.8223 - val_accuracy: 0.1344 - val_loss: 3.8130 - learning_rate: 0.0010
# Epoch 50/300
#
# Epoch 50: val_loss improved from 3.81295 to 3.80958, saving model to best_rnn_baseline.keras
# 🔎 Learning rate atual: 0.001000
# ⏱️ Tempo da época 50: 1.72s
# 57/57 - 2s - 30ms/step - accuracy: 0.1356 - loss: 3.8196 - val_accuracy: 0.1336 - val_loss: 3.8096 - learning_rate: 0.0010
# Epoch 51/300
#
# Epoch 51: val_loss improved from 3.80958 to 3.80673, saving model to best_rnn_baseline.keras
# 🔎 Learning rate atual: 0.001000
# ⏱️ Tempo da época 51: 1.72s
# 57/57 - 2s - 30ms/step - accuracy: 0.1359 - loss: 3.8173 - val_accuracy: 0.1345 - val_loss: 3.8067 - learning_rate: 0.0010
# Epoch 52/300
#
# Epoch 52: val_loss improved from 3.80673 to 3.80364, saving model to best_rnn_baseline.keras
# 🔎 Learning rate atual: 0.001000
# ⏱️ Tempo da época 52: 1.74s
# 57/57 - 2s - 31ms/step - accuracy: 0.1362 - loss: 3.8151 - val_accuracy: 0.1339 - val_loss: 3.8036 - learning_rate: 0.0010
# Epoch 53/300
#
# Epoch 53: val_loss improved from 3.80364 to 3.80055, saving model to best_rnn_baseline.keras
# 🔎 Learning rate atual: 0.001000
# ⏱️ Tempo da época 53: 1.66s
# 57/57 - 2s - 29ms/step - accuracy: 0.1364 - loss: 3.8127 - val_accuracy: 0.1342 - val_loss: 3.8005 - learning_rate: 0.0010
# Epoch 54/300
#
# Epoch 54: val_loss improved from 3.80055 to 3.79868, saving model to best_rnn_baseline.keras
# 🔎 Learning rate atual: 0.001000
# ⏱️ Tempo da época 54: 1.68s
# 57/57 - 2s - 30ms/step - accuracy: 0.1367 - loss: 3.8106 - val_accuracy: 0.1341 - val_loss: 3.7987 - learning_rate: 0.0010
# Epoch 54: early stopping
# Restoring model weights from the end of the best epoch: 52.
# ✅ Treinamento finalizado.

# %% [markdown]
# ## 8. Salvando o Modelo Treinado com Timestamp (.keras)
#
# Salva o modelo treinado no formato Keras (.keras), incluindo o timestamp no nome do arquivo para evitar sobrescrita em execuções futuras.

# %%
if not latest_keras:
    timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
    keras_path = f"rnn_baseline_{timestamp}.keras"
    print(f"💾 Salvando modelo em: {keras_path}")
    model.save(keras_path)
    print("✅ Modelo .keras salvo com sucesso.")
# Out:
# 💾 Salvando modelo em: rnn_baseline_20251003_051317.keras
# ✅ Modelo .keras salvo com sucesso.

# %% [markdown]
# ## 9. Avaliação
#
# Avaliação do modelo no conjunto de teste, com métricas detalhadas e visualizações.

# %%
print("🧪 Avaliando modelo no conjunto de teste...")
y_proba = model.predict(test_ds, batch_size=BATCH_SIZE)
y_pred = np.argmax(y_proba, axis=1)
int_to_product = {v: k for k, v in product_to_int.items()}


def avaliar_classificacao(y_true, y_pred, y_proba, int_to_product, k_list=None, top_n_cm=20):
    if k_list is None:
        k_list = [1, 3, 5]
    labels, counts = np.unique(y_true, return_counts=True)
    target_names = [str(int_to_product[l]) for l in labels]
    print("\n📊 Relatório de classificação:")
    report_dict = classification_report(
        y_true, y_pred, labels=labels, target_names=target_names, zero_division=0, output_dict=True
    )
    print(classification_report(
        y_true, y_pred, labels=labels, target_names=target_names, zero_division=0
    ))
    for k in k_list:
        topk_acc = top_k_accuracy_score(
            y_true, y_proba, k=k, labels=np.arange(y_proba.shape[1])
        )
        print(f"Top-{k} Accuracy: {topk_acc:.4f}")
 

    # Evolução do treinamento
    plt.figure(figsize=(10, 6))
    plt.plot(history.history['loss'], label='Treino (loss)')
    plt.plot(history.history['val_loss'], label='Validação (loss)')
    plt.xlabel('Épocas')
    plt.ylabel('Loss')
    plt.title('Evolução do treinamento')
    plt.legend()
    plt.grid(True)
    plt.show()


    # Matriz de confusão (Top N)
    top_classes = labels[np.argsort(counts)[-top_n_cm:]]
    top_target_names = [str(int_to_product[l]) for l in top_classes]
    cm = confusion_matrix(y_true, y_pred, labels=top_classes)
    plt.figure(figsize=(12, 10))
    sns.heatmap(
        cm, annot=True, fmt="d", cmap="Blues",
        xticklabels=top_target_names, yticklabels=top_target_names
    )
    plt.xlabel("Previsto (SKU)")
    plt.ylabel("Real (SKU)")
    plt.title(f"Matriz de Confusão (Top {top_n_cm} produtos mais frequentes)")
    plt.show()
    # Distribuição das confianças
    plt.figure(figsize=(8, 5))
    plt.hist(np.max(y_proba, axis=1), bins=20, alpha=0.7, color='skyblue', edgecolor='black')
    plt.title("Distribuição das Confianças (probabilidade máxima prevista)")
    plt.xlabel("Probabilidade")
    plt.ylabel("Frequência")
    plt.show()
    # Contagem de classes
    print("\n📈 Análise de Desequilíbrio de Classes:")
    df_counts = pd.DataFrame({'SKU': target_names, 'Contagem': counts})
    df_counts = df_counts.sort_values(by='Contagem', ascending=False).head(top_n_cm)
    plt.figure(figsize=(12, 5))
    sns.barplot(x='SKU', y='Contagem', data=df_counts, palette="viridis", legend=False)
    plt.title(f"Contagem de Ocorrências (Top {top_n_cm} SKUs no Teste)")
    plt.xlabel("SKU")
    plt.ylabel("Contagem (Amostras Reais)")
    plt.xticks(rotation=45, ha='right')
    plt.show()
    # Métricas por classe
    print("\n⭐ Análise Detalhada de Métricas por SKU:")
    df_metrics = pd.DataFrame(report_dict).transpose()
    df_metrics = df_metrics.iloc[:-3]
    df_metrics = df_metrics.reset_index().rename(columns={'index': 'SKU'})
    df_metrics = df_metrics[df_metrics['SKU'].isin(top_target_names)]
    plt.figure(figsize=(12, 5))
    sns.barplot(
        x='SKU',
        y='f1-score',
        data=df_metrics.sort_values(by='f1-score', ascending=False),
        palette="coolwarm",
        legend=False
    )
    plt.title(f"F1-Score por SKU (Top {top_n_cm} Classes)")
    plt.xlabel("SKU")
    plt.ylabel("F1-Score")
    plt.xticks(rotation=45, ha='right')
    plt.ylim(0, 1.0)
    plt.grid(axis='y', linestyle='--')
    plt.show()
    # Precision e Recall juntos
    df_metrics_melted = df_metrics.melt(id_vars='SKU', value_vars=['precision', 'recall'], var_name='Métrica',
                                        value_name='Valor')
    plt.figure(figsize=(15, 6))
    sns.barplot(x='SKU', y='Valor', hue='Métrica', data=df_metrics_melted, palette="Set2")
    plt.title(f"Precision vs. Recall por SKU (Top {top_n_cm} Classes)")
    plt.xlabel("SKU")
    plt.ylabel("Valor da Métrica")
    plt.xticks(rotation=45, ha='right')
    plt.ylim(0, 1.0)
    plt.legend(loc='upper right')
    plt.grid(axis='y', linestyle='--')
    plt.show()


avaliar_classificacao(y_test, y_pred, y_proba, int_to_product)
print("✅ Avaliação finalizada.\n")
print("\n🏁 Script finalizado com sucesso!")
# Out:
# 🧪 Avaliando modelo no conjunto de teste...
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 1s 673ms/step
# 2025-10-03 10:59:30.660894: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_12', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-10-03 10:59:30.661681: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_13', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-10-03 10:59:30.777119: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_901', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-10-03 10:59:30.989427: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_13', 60 bytes spill stores, 60 bytes spill loads
#
# 2025-10-03 10:59:31.014165: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_12', 60 bytes spill stores, 60 bytes spill loads
#
# 2025-10-03 10:59:31.029608: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_901', 64 bytes spill stores, 64 bytes spill loads
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 475ms/step
#
# 📊 Relatório de classificação:
#               precision    recall  f1-score   support
#
#          709       0.43      0.56      0.48       156
#          710       0.00      0.00      0.00        79
#          712       0.08      0.22      0.12       712
#          713       0.50      0.01      0.01       160
#          714       0.03      0.00      0.01       445
#          715       0.07      0.17      0.10       701
#          716       0.00      0.00      0.00        65
#          717       0.03      0.01      0.01       243
#          718       0.08      0.00      0.01       323
#          719       0.00      0.00      0.00        18
#          721       0.41      0.42      0.41        60
#          723       0.08      0.12      0.10       118
#          724       0.00      0.00      0.00       112
#          725       0.07      0.16      0.10       936
#          726       0.14      0.02      0.03       356
#          727       0.00      0.00      0.00         6
#          728       0.10      0.17      0.13       840
#          729       0.09      0.16      0.12       435
#          730       0.08      0.03      0.05       150
#          731       0.00      0.00      0.00        89
#          732       0.33      0.02      0.03       166
#          733       0.00      0.00      0.00       186
#          734       0.00      0.00      0.00        46
#          735       0.00      0.00      0.00       328
#          711       0.07      0.06      0.06       651
#          736       0.06      0.01      0.02       579
#          737       0.05      0.06      0.06       150
#          738       0.11      0.12      0.11       775
#          739       0.00      0.00      0.00        57
#          740       0.00      0.00      0.00        47
#          741       0.30      0.02      0.03       177
#          742       0.36      0.31      0.33        13
#          743       0.12      0.28      0.16      1371
#          744       0.00      0.00      0.00        28
#          745       0.06      0.01      0.01       275
#          746       0.09      0.01      0.01       386
#          747       0.00      0.00      0.00        69
#          748       0.00      0.00      0.00         1
#          749       0.00      0.00      0.00       179
#          751       0.00      0.00      0.00         5
#          752       0.11      0.36      0.17      1440
#          753       0.00      0.00      0.00        33
#          754       0.00      0.00      0.00        17
#          755       0.00      0.00      0.00        91
#          756       0.17      0.01      0.02        76
#          757       0.35      0.44      0.39        34
#          758       0.00      0.00      0.00       222
#          759       0.04      0.08      0.05       524
#          760       0.08      0.05      0.06       385
#          762       0.04      0.01      0.02       104
#          764       0.00      0.00      0.00        66
#          765       0.00      0.00      0.00        46
#          766       0.00      0.00      0.00        79
#          767       0.00      0.00      0.00        11
#          768       0.00      0.00      0.00        33
#          769       0.14      0.01      0.01       159
#          770       0.00      0.00      0.00        26
#          771       0.03      0.03      0.03       235
#          772       0.25      0.25      0.25       107
#          773       0.00      0.00      0.00        28
#          774       0.15      0.14      0.14        37
#          775       0.00      0.00      0.00        14
#          776       0.00      0.00      0.00        58
#          777       0.02      0.02      0.02        91
#          778       0.00      0.00      0.00        80
#          779       0.08      0.01      0.02       214
#          780       0.00      0.00      0.00        70
#          781       0.08      0.08      0.08        39
#          782       0.16      0.07      0.10       191
#          783       0.00      0.00      0.00        69
#          784       0.00      0.00      0.00         2
#          786       0.00      0.00      0.00        63
#          787       0.07      0.02      0.03       124
#          788       0.00      0.00      0.00        96
#          790       0.00      0.00      0.00        30
#          791       0.06      0.02      0.03       356
#          792       0.00      0.00      0.00        57
#          793       0.00      0.00      0.00        25
#          794       0.00      0.00      0.00        34
#          795       0.04      0.03      0.03       251
#          796       0.20      0.02      0.04        50
#          797       0.08      0.06      0.07        82
#          798       0.04      0.01      0.02        87
#          799       0.00      0.00      0.00        64
#          800       0.00      0.00      0.00        54
#          801       0.12      0.02      0.03        57
#          802       0.07      0.02      0.03        91
#          803       0.00      0.00      0.00        37
#          804       0.00      0.00      0.00        65
#          805       0.00      0.00      0.00        16
#          806       0.00      0.00      0.00        70
#          807       0.00      0.00      0.00        26
#          808       0.00      0.00      0.00       126
#          809       0.03      0.01      0.01       285
#          812       0.25      0.06      0.09        18
#          813       0.14      0.02      0.03        56
#          814       0.23      0.01      0.02       232
#          817       0.00      0.00      0.00        24
#          819       0.03      0.03      0.03        40
#          820       0.07      0.01      0.02        68
#          821       0.24      0.07      0.11        58
#          823       0.00      0.00      0.00        12
#          824       0.00      0.00      0.00        64
#          826       0.00      0.00      0.00         7
#          827       0.00      0.00      0.00       192
#          828       0.00      0.00      0.00        18
#          829       0.00      0.00      0.00        56
#          832       0.00      0.00      0.00        17
#          833       0.00      0.00      0.00        17
#          834       0.00      0.00      0.00         1
#          837       0.00      0.00      0.00        98
#          840       0.00      0.00      0.00         7
#          841       0.00      0.00      0.00        14
#          843       0.11      0.03      0.05        29
#          844       0.00      0.00      0.00        33
#          847       0.00      0.00      0.00         9
#          854       0.09      0.02      0.03       520
#          856       0.00      0.00      0.00        38
#          857       0.05      0.02      0.03        45
#          860       0.00      0.00      0.00        85
#          862       0.06      0.02      0.02        65
#          863       0.14      0.04      0.06        25
#          864       0.00      0.00      0.00        27
#          865       0.00      0.00      0.00         9
#          868       0.00      0.00      0.00         3
#          869       0.08      0.01      0.01       193
#          872       0.00      0.00      0.00        51
#          874       0.00      0.00      0.00         3
#          880       0.00      0.00      0.00         1
#          881       0.00      0.00      0.00         9
#          882       0.00      0.00      0.00        29
#          884       0.00      0.00      0.00         4
#          889       0.00      0.00      0.00         2
#          890       0.00      0.00      0.00         6
#          893       0.00      0.00      0.00         3
#          894       0.00      0.00      0.00         3
#          895       0.24      0.19      0.21        26
#          899       0.00      0.00      0.00        54
#          900       0.00      0.00      0.00        38
#          902       0.00      0.00      0.00       120
#          911       0.18      0.04      0.07        90
#          913       0.04      0.01      0.01       119
#          922       0.12      0.02      0.03        53
#          923       0.00      0.00      0.00         1
#          925       0.11      0.17      0.14       274
#          928       0.08      0.03      0.04       222
#          930       0.14      0.09      0.11        11
#          934       0.20      0.33      0.25       337
#          936       0.05      0.02      0.03       148
#          937       0.00      0.00      0.00         4
#          944       0.27      0.34      0.30       176
#          947       0.00      0.00      0.00        61
#          949       0.17      0.07      0.10        15
#          956       0.35      0.29      0.32        55
#          957       0.32      0.29      0.30       178
#          972       0.00      0.00      0.00         1
#          973       0.00      0.00      0.00         1
#          990       0.28      0.36      0.31        78
#          995       0.00      0.00      0.00        24
#          998       0.00      0.00      0.00         2
#         1008       0.00      0.00      0.00         3
#         1010       0.00      0.00      0.00        45
#         1016       0.00      0.00      0.00         1
#         1020       0.00      0.00      0.00         1
#         1024       0.00      0.00      0.00         4
#         1025       0.00      0.00      0.00         5
#         1026       0.25      0.15      0.19        26
#         1027       0.34      0.28      0.31        85
#         1029       0.00      0.00      0.00        12
#         1033       0.00      0.00      0.00        70
#         1037       0.00      0.00      0.00         3
#         1040       0.00      0.00      0.00        58
#         1041       0.00      0.00      0.00        88
#         1043       0.00      0.00      0.00         7
#         1044       0.16      0.03      0.05        95
#         1042       0.00      0.00      0.00        85
#         1045       0.00      0.00      0.00        10
#         1046       0.00      0.00      0.00        93
#         1048       0.00      0.00      0.00         5
#         1050       0.00      0.00      0.00         4
#         1064       0.00      0.00      0.00        25
#         1052       0.00      0.00      0.00         5
#         1066       0.00      0.00      0.00         2
#         1047       0.00      0.00      0.00         5
#         1071       0.00      0.00      0.00        34
#         1072       0.00      0.00      0.00         5
#         1055       0.00      0.00      0.00         2
#         1054       0.00      0.00      0.00         2
#         1056       0.00      0.00      0.00         4
#         1057       0.00      0.00      0.00         1
#         1075       0.00      0.00      0.00         4
#         1076       0.00      0.00      0.00         4
#         1077       0.00      0.00      0.00         7
#         1078       0.00      0.00      0.00        20
#         1080       0.00      0.00      0.00         3
#         1081       0.00      0.00      0.00        30
#         1070       0.00      0.00      0.00         1
#         1063       0.00      0.00      0.00         2
#         1084       0.00      0.00      0.00         2
#         1085       0.00      0.00      0.00        40
#         1051       0.00      0.00      0.00         1
#         1067       0.00      0.00      0.00         1
#
#    micro avg       0.10      0.10      0.10     23399
#    macro avg       0.05      0.04      0.04     23399
# weighted avg       0.09      0.10      0.07     23399
#
# Top-1 Accuracy: 0.1022
# Top-3 Accuracy: 0.2202
# Top-5 Accuracy: 0.3016
# 📈 Análise de Desequilíbrio de Classes:
# /tmp/ipykernel_5358/280741549.py:62: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='SKU', y='Contagem', data=df_counts, palette="viridis", legend=False)
# ⭐ Análise Detalhada de Métricas por SKU:
# /tmp/ipykernel_5358/280741549.py:75: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# ✅ Avaliação finalizada.
#
#
# 🏁 Script finalizado com sucesso!
